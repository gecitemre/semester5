# %%
import numpy
from matplotlib import pyplot
import latexify

d = numpy.linspace(0,500,2000)
x, y = numpy.meshgrid(d,d)
feasible_region = ((3*x+6*y<=900) & (5*x+4*y<=1200) & (x>=0) & (y>=0)).astype(int)
pyplot.imshow(feasible_region, extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greys", alpha = 0.3)


# plot the lines defining the constraints
x_ = numpy.linspace(0, 500, 200)
# 3x + 2y <= 900
wool_constraint = (900 - 3*x_)/6
# 5x + 4y <= 1200
cotton_constraint = (1200 - 5*x_)/4
# x>=0, y>=0
cardinality_constraint = numpy.zeros_like(x_)
# isoprophit line
solution = 200 - 12 * x_ / 16

# Make plot
pyplot.plot(x_, wool_constraint, label="Wool constraint")
pyplot.plot(x_, cotton_constraint, label="Cotton constraint")
pyplot.plot(x_, solution, label="Solution line")
pyplot.ylim(bottom=0)
pyplot.legend()
pyplot.xlabel("x")
pyplot.ylabel("y")
pyplot.savefig("q1a.png")

# %%
pyplot.imshow(feasible_region, extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greys", alpha = 0.3)
solution = (3250 - 12 * x_) / 17
pyplot.plot(x_, wool_constraint, label="Wool constraint")
pyplot.plot(x_, cotton_constraint, label="Cotton constraint")
pyplot.plot(x_, solution, label="Solution line")
pyplot.ylim(bottom=0)
pyplot.legend()
pyplot.xlabel("x")
pyplot.ylabel("y")
pyplot.savefig("q1b.png")

# %%
pyplot.imshow(feasible_region, extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greys", alpha = 0.3)
solution = 23 * (240 - x_) / 16
pyplot.plot(x_, wool_constraint, label="Wool constraint")
pyplot.plot(x_, cotton_constraint, label="Cotton constraint")
pyplot.plot(x_, solution, label="Solution line")
pyplot.ylim(bottom=0)
pyplot.legend()
pyplot.xlabel("x")
pyplot.ylabel("y")
pyplot.savefig("q1c.png")

# %%
pyplot.imshow(feasible_region, extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greys", alpha = 0.3)
solution = 200 - 12 * x_ / 16
wool_constraint = (1200 - 3*x_)/6
pyplot.plot(x_, wool_constraint, label="Wool constraint")
pyplot.plot(x_, cotton_constraint, label="Cotton constraint")
pyplot.plot(x_, solution, label="Solution line")
pyplot.ylim(bottom=0)
pyplot.legend()
pyplot.xlabel("x")
pyplot.ylabel("y")
pyplot.savefig("q1a.png")
